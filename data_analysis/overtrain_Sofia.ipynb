# %% [markdown]
# ## Plot validation loss and training loss against epoch

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_and_save_loss(csv_file_path, save_plot = False, output_file_path = None):
    # Read the CSV file
    data = pd.read_csv(csv_file_path, sep='\t')  # Use tab separator for your data

    epoch = data['epoch']
    training_loss = data['training_loss']
    validation_loss = data['validation_loss']

    # Plot the training and validation loss against epochs
    plt.figure(figsize=(5, 3))
    
    plt.plot(epoch, training_loss, label='Training Loss', color='blue')
    plt.plot(epoch, validation_loss, label='Validation Loss', color='orange')
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss vs. Epochs')
    plt.legend()
    plt.grid(True)
    plt.ylim(0, 1)
    # plt.xlim(0,30)
    
    # Show the plot
    plt.show()

    if save_plot:
        # Save the figure
        plt.savefig(output_file_path, format='png')

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/comb/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# comb

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/mask/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# mask

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/aug/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# aug

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/base/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# base

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_13/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# Baseline: FractionInvalid + LR 0.0001

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_12/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# Baseline: FractionInvalid + LR 0.00001

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_11/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# Baseline: FractionInvalid + LR 0.0001

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_10/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# Baseline: TopKAccuracy

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_9/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# Baseline: FractionInvalid

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_8/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# Baseline: FractionInvalid + TopKAccuracy

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/forward_prediction/version_8/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# PRETRAIN: BS = 500

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/forward_prediction/version_7/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# PRETRAIN: BS = 128

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/forward_prediction/version_6/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# PRETRAIN: BS = 64

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_7/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# baseline

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/pretraining/forward_prediction/version_4/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# PRETRAIN: LR = 0.5, BS = 500

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_6/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# added randomisation_restricted

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_5/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# added randomisation_mcs_strict

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_4/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# added randomisation_mcs

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_3/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# added parent-parent and parent-grandchild

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_2/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# added parent-parent

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_1/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# added parent-grandchild

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# baseline
