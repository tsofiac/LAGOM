# %% [markdown]
# ## Plot validation loss and training loss against epoch

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_and_save_loss(csv_file_path, save_plot = False, output_file_path = None):
    # Read the CSV file
    data = pd.read_csv(csv_file_path, sep='\t')  # Use tab separator for your data

    epoch = data['epoch']
    training_loss = data['training_loss']
    validation_loss = data['validation_loss']

    # Plot the training and validation loss against epochs
    plt.figure(figsize=(5, 3))
    
    plt.plot(epoch, training_loss, label='Training Loss', color='blue')
    plt.plot(epoch, validation_loss, label='Validation Loss', color='orange')
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss vs. Epochs')
    plt.legend()
    plt.grid(True)
    plt.ylim(0, 1)
    
    # Show the plot
    plt.show()

    if save_plot:
        # Save the figure
        plt.savefig(output_file_path, format='png')

# %%
# Example usage
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_1/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# train = val

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_4/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# metxbio clean

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_5/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# metxbio clean and then unique parents

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_7/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# metxbiodb clean and unique parents. 100 epochs

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_3/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# drugbank clean

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_4/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# drugbank clean + unique

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_6/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# drugbank long

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_18/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# drugbank unique parent after filtering (new curation..)

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_19/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# metxbiodb unique parent after filtering

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_20/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# combined unique parent

# %%
csv_file_path ='/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_9/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# combined all

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/backward_prediction/version_21/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# combined all with groupshufflesplit

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_10/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# cleaned drugbank with groupshufflesplit

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_11/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# standardised and removed duplicates drugbank with groupshufflesplit

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/backward_prediction/version_12/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# clean metxbiodb with groupshufflesplit

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward combined 0 predictions

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_1/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward combined 1 predictions

# %%
csv_file_path = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/forward_prediction/version_2/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward combined 2 predictions

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/forward_prediction/version_0/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward, Combined dataset – clean (weight 100-750, fingerprint >0.20)

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/forward_prediction/version_1/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward, Combined dataset – clean (weight 100-750, fingerprint >0.20), augmentation prob = 0.5

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/forward_prediction/version_6/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward, Combined dataset – clean (weight 100-750, fingerprint >0.20), augmentation prob = 0 #gammal data??

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/forward_prediction/version_7/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward, Combined dataset – clean (weight 100-750, fingerprint >0.20), augmentation prob = 1 # gammal data??

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/forward_prediction/version_8/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward, Combined dataset – clean (weight 100-750, fingerprint >0.20), augmentation prob = 0.5

# %%
csv_file_path = '/projects/cc/se_users/carlsson_ksmq649/MasterThesis/results/training/forward_prediction/version_9/logged_train_metrics.csv'
plot_and_save_loss(csv_file_path)
# forward, Combined dataset – clean (weight 100-750, fingerprint >0.20), augmentation prob = 0
