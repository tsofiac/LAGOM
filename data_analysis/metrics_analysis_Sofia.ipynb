# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_metrics(csv_file_path, save_plot = False, output_file_path = None):
    # Read the CSV file
    data = pd.read_csv(csv_file_path, sep='\t')  # Use tab separator for your data

    epoch = data['epoch']
    training_loss = data['training_loss']
    metabolite_coverage_score = data['metabolite_coverage_score']
    top_1_metabolite_score = data['top_1_metabolite_score']
    validation_loss = data['validation_loss']

    # Plot the training and validation loss against epochs
    plt.figure(figsize=(5, 3))
    
    # plt.plot(epoch, training_loss, label='Training Loss', color='red')
    plt.plot(epoch, metabolite_coverage_score, label='Metabolite Coverage', color='blue')
    plt.plot(epoch, top_1_metabolite_score, label='Top-1 Metabolite', color='green')
    plt.plot(epoch, validation_loss, label='Validation Loss', color='orange')
    
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss vs. Epochs')
    plt.legend()
    plt.grid(True)
    plt.ylim(0, 1)
    # plt.xlim(0,30)
    
    # Show the plot
    plt.show()

    if save_plot:
        # Save the figure
        plt.savefig(output_file_path, format='png')

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_8/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Csp3

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_7/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# LogP+Csp3 epoch=26

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_5/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# LogP epoch=42

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_4/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Baseline epoch=46

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_3/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# PP-PG rand epoch=55

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_2/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# PG rand epoch=40

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_1/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# PP rand epoch=24

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/alohomora/forward_prediction/version_0/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Baseline rand epoch=52

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_6/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Baseline epoch=63

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_7/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Csp3 epoch=70 (under 100 otherwise 132)

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_8/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# LogP epoch=68

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_9/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Csp3+LogP epoch=55

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_2/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# Baseline 0.5 epoch=81

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_3/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# PG 0.5 epoch=56

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_4/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# PP 0.5 epoch=110 and epoch=66

# %%
file = '/projects/cc/se_users/larsson_kbvs588/test/MasterThesis/results/training/submitted/forward_prediction/version_5/logged_train_metrics.csv'
plot_metrics(file, save_plot = False, output_file_path = None)
# PG-PP 0.5 epoch=67
