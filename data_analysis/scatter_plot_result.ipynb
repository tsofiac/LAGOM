# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = [1, 2, 10, 2, 3, 3, 2, 2, 2, 2, 2, 1, 6, 4, 2, 4, 6, 2, 7, 1, 6, 5, 7, 1, 2, 4, 5, 1, 2, 7, 3, 4, 7, 12, 2, 2, 2]
y = [1, 2, 3, 0, 0, 0, 2, 2, 1, 1, 0, 0, 1, 4, 2, 1, 3, 0, 1, 1, 0, 0, 2, 0, 0, 1, 0, 0, 1, 3, 0, 1, 4, 0, 1, 1, 1]

plt.plot(x, y, '.')
plt.xlabel('Number of metabolites')
plt.ylabel('Number of predicted metabolites')
plt.ylim(0, 12)
plt.ylim(0, 12)

plt.show()
