# %%
from rdkit import Chem
from rdkit.Chem import Draw
import os
from IPython.display import display

# %%
def draw_mol(smiles, save_figure=None):

    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        raise ValueError("Invalid SMILES string provided.")
    
    img = Draw.MolToImage(mol, size=(400, 400), dpi=300)
    display(img)
    
    if save_figure is not None:
        os.makedirs('molecules', exist_ok=True)
        img.save(f'molecules/{save_figure}.png', format='PNG')

# %%
smiles = "CC(=O)Oc1ccccc1C(=O)O"
draw_mol(smiles, 'aspirin')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=400x400>
